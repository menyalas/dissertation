# %% [markdown]
# ## Merge topic labels to chunk dataframe

# %%
import pickle
import gensim
from gensim import models
import gensim.corpora as corpora
import pandas as pd
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)
from pprint import pprint

# %% [markdown]
# ## Get Resources

# %%
# Lemmanized text
with open("20240405_PhD_LtrChkLem-N.txt", "rb") as fp:   # Unpickling
    data_lemmatized = pickle.load(fp)

# %%
ldamodel = models.ldamodel.LdaModel.load('20240406_PhD_TopicLtrChkMAL23')

# %%
# Not needed because I converted from Mallet to LDA in 20240331_PhD_TopicLetterChkNV-Mallet
# Load saved mallet
# lda_mallet = gensim.models.wrappers.LdaMallet.load("20240221_PhD_TopicChkMAL14")
# Convert to LDA
# ldamodel = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(lda_mallet)

# %%
pprint(sorted(ldamodel.print_topics(num_words=10)))
# Out:
# [(0,
#   '0.127*"life" + 0.051*"death" + 0.043*"mind" + 0.028*"manner" + 0.024*"soul" '
#   '+ 0.021*"nature" + 0.020*"trial" + 0.017*"truth" + 0.016*"coal" + '
#   '0.016*"matter"'),
#  (1,
#   '0.132*"land" + 0.079*"acre" + 0.073*"year" + 0.071*"farm" + 0.034*"wheat" + '
#   '0.032*"dollar" + 0.029*"farmer" + 0.024*"crop" + 0.024*"price" + '
#   '0.023*"bushel"'),
#  (2,
#   '0.035*"body" + 0.033*"air" + 0.032*"food" + 0.023*"night" + 0.022*"head" + '
#   '0.022*"arm" + 0.020*"blood" + 0.019*"pain" + 0.017*"drink" + 0.016*"heat"'),
#  (3,
#   '0.154*"child" + 0.145*"letter" + 0.035*"friend" + 0.032*"heart" + '
#   '0.031*"baby" + 0.031*"kind" + 0.022*"write" + 0.021*"boy" + 0.020*"news" + '
#   '0.020*"girl"'),
#  (4,
#   '0.047*"water" + 0.033*"tea" + 0.025*"pork" + 0.023*"bread" + 0.022*"thing" '
#   '+ 0.020*"piece" + 0.019*"box" + 0.016*"pound" + 0.016*"butter" + '
#   '0.016*"sugar"'),
#  (6,
#   '0.123*"school" + 0.057*"church" + 0.038*"number" + 0.030*"teacher" + '
#   '0.024*"pupil" + 0.023*"town" + 0.022*"service" + 0.022*"territory" + '
#   '0.021*"interest" + 0.019*"native"'),
#  (8,
#   '0.166*"time" + 0.129*"day" + 0.085*"week" + 0.053*"thing" + 0.045*"trouble" '
#   '+ 0.045*"return" + 0.034*"change" + 0.027*"pleasure" + 0.024*"visit" + '
#   '0.023*"comfort"'),
#  (9,
#   '0.072*"book" + 0.054*"paper" + 0.026*"copy" + 0.023*"interest" + '
#   '0.023*"letter" + 0.021*"story" + 0.019*"term" + 0.016*"history" + '
#   '0.016*"notice" + 0.015*"picture"'),
#  (10,
#   '0.051*"man" + 0.035*"mine" + 0.028*"time" + 0.027*"reason" + 0.021*"number" '
#   '+ 0.018*"distance" + 0.018*"wagon" + 0.016*"claim" + 0.015*"tribe" + '
#   '0.014*"mountain"'),
#  (11,
#   '0.050*"city" + 0.050*"place" + 0.039*"river" + 0.035*"town" + '
#   '0.030*"village" + 0.029*"boat" + 0.028*"inhabitant" + 0.025*"bank" + '
#   '0.025*"mill" + 0.023*"world"'),
#  (12,
#   '0.069*"girl" + 0.040*"eye" + 0.033*"boy" + 0.028*"character" + '
#   '0.023*"woman" + 0.022*"head" + 0.022*"scene" + 0.020*"lady" + 0.019*"study" '
#   '+ 0.019*"care"'),
#  (13,
#   '0.064*"winter" + 0.047*"summer" + 0.044*"tree" + 0.039*"foot" + '
#   '0.037*"horse" + 0.036*"spring" + 0.036*"wood" + 0.026*"kind" + '
#   '0.026*"flower" + 0.024*"garden"'),
#  (14,
#   '0.168*"country" + 0.123*"money" + 0.037*"pound" + 0.029*"difficulty" + '
#   '0.026*"account" + 0.023*"person" + 0.021*"expense" + 0.021*"purchase" + '
#   '0.020*"quarter" + 0.017*"pay"'),
#  (15,
#   '0.117*"family" + 0.103*"year" + 0.089*"friend" + 0.054*"wife" + '
#   '0.045*"husband" + 0.039*"daughter" + 0.035*"health" + 0.021*"kind" + '
#   '0.020*"living" + 0.019*"woman"'),
#  (16,
#   '0.051*"time" + 0.050*"case" + 0.040*"hospital" + 0.033*"patient" + '
#   '0.032*"doctor" + 0.030*"train" + 0.030*"room" + 0.029*"question" + '
#   '0.024*"answer" + 0.024*"care"'),
#  (17,
#   '0.099*"dollar" + 0.059*"month" + 0.057*"board" + 0.055*"cent" + 0.036*"day" '
#   '+ 0.034*"wage" + 0.030*"servant" + 0.021*"employment" + 0.020*"hour" + '
#   '0.019*"rate"'),
#  (18,
#   '0.073*"week" + 0.064*"day" + 0.059*"morning" + 0.053*"bed" + 0.047*"night" '
#   '+ 0.043*"evening" + 0.030*"clock" + 0.026*"yesterday" + 0.024*"walk" + '
#   '0.024*"today"'),
#  (19,
#   '0.150*"place" + 0.143*"house" + 0.059*"people" + 0.037*"person" + '
#   '0.033*"time" + 0.027*"building" + 0.025*"store" + 0.022*"gentleman" + '
#   '0.022*"street" + 0.021*"stone"'),
#  (20,
#   '0.039*"ship" + 0.036*"company" + 0.026*"captain" + 0.024*"vessel" + '
#   '0.024*"gold" + 0.023*"passenger" + 0.022*"year" + 0.022*"time" + '
#   '0.021*"month" + 0.020*"arrival"'),
#  (21,
#   '0.071*"room" + 0.070*"hand" + 0.043*"door" + 0.034*"table" + 0.029*"hour" + '
#   '0.026*"fear" + 0.024*"stage" + 0.023*"gentleman" + 0.020*"window" + '
#   '0.019*"rest"')]

# %%
# Metadata
df = pd.read_csv("20240405_PhD_Data4TopicModel-LetterChunk.csv") 
df = df.rename(columns={'Unnamed: 0':'docID-AT'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2270 entries, 0 to 2269
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   docID-AT          2270 non-null   int64
#  1   docauthorid       2270 non-null   object
#  2   docauthorname     2270 non-null   object
#  3   docid             2270 non-null   object
#  4   docyear           2235 non-null   float64
#  5   docmonth          2171 non-null   float64
#  6   authorgender      2270 non-null   object
#  7   agewriting        1536 non-null   float64
#  8   agedeath          1525 non-null   float64
#  9   relMin            1870 non-null   object
#  10  nationalOrigin    2266 non-null   object
#  11  authorLocation    2270 non-null   object
#  12  U                 2076 non-null   object
#  13  M                 2076 non-null   object
#  14  S                 2076 non-null   object
#  15  F                 2076 non-null   object
#  16  L                 2076 non-null   object
#  17  text              2270 non-null   object
#  18  sequence          2270 non-null   int64
#  19  scoreNeg          2270 non-null   float64
#  20  scorePos          2270 non-null   float64
#  21  scoreNeu          2270 non-null   float64
#  22  scoreCompound     2270 non-null   float64
#  23  totalTokens       2270 non-null   int64
#  24  uniqueTokens      2270 non-null   int64
#  25  lexicalDiversity  2270 non-null   float64
#  26  chunks            2270 non-null   int64
#  27  position          2270 non-null   float64
# dtypes: float64(10), int64(5), object(13)
# memory usage: 496.7+ KB

# %%
data = df.text.values.tolist()
# data[0]

# %% [markdown]
# # Create Functions & Objects

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
def format_topics(ldamodel=ldamodel, corpus=corpus, texts=texts):
    # Init output
    topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                topics_df = topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    topics_df = pd.concat([topics_df, contents], axis=1)
    return(topics_df)

# %%
# Check the topic for the first 10 rows. 
df_topic_keywords = format_topics(ldamodel=ldamodel, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0               7              0.0855
# 1            1              10              0.0860
# 2            2              10              0.1045
# 3            3              21              0.0900
# 4            4              21              0.1162
#
#                                             Keywords  \
# 0  mind, order, call, man, companion, judge, hour...
# 1  man, mine, time, reason, number, distance, wag...
# 2  man, mine, time, reason, number, distance, wag...
# 3  room, hand, door, table, hour, fear, stage, ge...
# 4  room, hand, door, table, hour, fear, stage, ge...
#
#                                                 Text
# 0  TRINIDAD On Train from Steubenville Ohio to Ci...
# 1  in the island of Cuba. So we concluded that Cu...
# 2  Trinidad." "Where is Trinidad?" "A little mini...
# 3  frighten me any more than others who will be t...
# 4  good to anyone in need. He died possessed of t...

# %%
map_Text_topicNumber = {}

# %%
for index, item in enumerate(data):
    topic_dist = ldamodel.get_document_topics(corpus[index])

    # topic_dist is a list of tuples: each tuple has a topic number with its corresponding proportion
    sorted_topic_dist = sorted(topic_dist, key=lambda x: (x[1]), reverse=True) # Sort it in descending order
    
    # Pick the top one:
    topic_number = sorted_topic_dist[0][0]
    map_Text_topicNumber[item] = topic_number

# %%
# View the first key value pair in dictionary (text, label)
# dict(list(map_Text_topicNumber.items())[0:1])

# %%
df['topicNumber'] = df['text'].map(map_Text_topicNumber)
df.loc[:10,['docid', 'docauthorid', 'text', 'topicNumber']]
# Out:
#          docid docauthorid                                               text  \
# 0   S1019-D002  per0001043  TRINIDAD On Train from Steubenville Ohio to Ci...
# 1   S1019-D002  per0001043  in the island of Cuba. So we concluded that Cu...
# 2   S1019-D002  per0001043  Trinidad." "Where is Trinidad?" "A little mini...
# 3   S1019-D002  per0001043  frighten me any more than others who will be t...
# 4   S1019-D002  per0001043  good to anyone in need. He died possessed of t...
# 5   S1019-D002  per0001043  I met Sisters Gabriella and Delphina walking i...
# 6   S1019-D002  per0001043  interest. You know that up to date the Sisters...
# 7   S1019-D002  per0001043  mother kept quiet. When we were permitted a lo...
# 8   S1019-D002  per0001043  to visit our Ecclesiastical Superior. The Most...
# 9   S1019-D002  per0001043  must not go on this far away mission! Are you ...
# 10  S1019-D002  per0001043  had seen me during the greater part of last ni...
#
#     topicNumber
# 0             7
# 1            10
# 2            10
# 3            21
# 4            21
# 5            12
# 6             6
# 7            15
# 8             2
# 9            16
# 10           16

# %%
# Group top 5 sentences under each topic
topics_sorteddf_mallet = pd.DataFrame()

topics_outdf_grpd = df_topic_keywords.groupby('Dominant_Topic')

for i, grp in topics_outdf_grpd:
    topics_sorteddf_mallet = pd.concat([topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
topics_sorteddf_mallet
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0           0              0.3772
# 1           1              0.5846
# 2           2              0.5005
# 3           3              0.2874
# 4           4              0.4382
# 5           5              0.3006
# 6           6              0.3353
# 7           7              0.3374
# 8           8              0.1748
# 9           9              0.3132
# 10         10              0.3826
# 11         11              0.3915
# 12         12              0.2809
# 13         13              0.3477
# 14         14              0.2663
# 15         15              0.3006
# 16         16              0.3785
# 17         17              0.3242
# 18         18              0.2395
# 19         19              0.2425
# 20         20              0.3903
# 21         21              0.3489
# 22         22              0.3927
#
#                                              Keywords  \
# 0   life, death, mind, manner, soul, nature, trial...
# 1   land, acre, year, farm, wheat, dollar, farmer,...
# 2   body, air, food, night, head, arm, blood, pain...
# 3   child, letter, friend, heart, baby, kind, writ...
# 4   water, tea, pork, bread, thing, piece, box, po...
# 5   work, day, man, business, trade, hand, carpent...
# 6   school, church, number, teacher, pupil, town, ...
# 7   mind, order, call, man, companion, judge, hour...
# 8   time, day, week, thing, trouble, return, chang...
# 9   book, paper, copy, interest, letter, story, te...
# 10  man, mine, time, reason, number, distance, wag...
# 11  city, place, river, town, village, boat, inhab...
# 12  girl, eye, boy, character, woman, head, scene,...
# 13  winter, summer, tree, foot, horse, spring, woo...
# 14  country, money, pound, difficulty, account, pe...
# 15  family, year, friend, wife, husband, daughter,...
# 16  time, case, hospital, patient, doctor, train, ...
# 17  dollar, month, board, cent, day, wage, servant...
# 18  week, day, morning, bed, night, evening, clock...
# 19  place, house, people, person, time, building, ...
# 20  ship, company, captain, vessel, gold, passenge...
# 21  room, hand, door, table, hour, fear, stage, ge...
# 22  people, government, state, law, country, idea,...
#
#                                                  Text
# 0   to all that mediums tell you. They are often d...
# 1   that crop 485 Harvesting and threshing wheat 1...
# 2   minutes or about fourteen times in an hour. I ...
# 3   wrote quite in a huff ‘Supposing I was home an...
# 4   pleasant and salt cod particularly so when eat...
# 5   may lose much time and money (to him how preci...
# 6   draft a bill that will be tabled. Do listen to...
# 7   to walk between the sheriff and Sister to the ...
# 8   Sarah to Martha November 13 The tidings of dea...
# 9   and possesses much dramatic effect and it coul...
# 10  from Junction City. At noon four Indians visit...
# 11  boat-building village: also Blackrock near Buf...
# 12  the devout. Not a native woman wears any other...
# 13  price. The average price for the last four or ...
# 14  E near Guelph May 30th 1832. Dear Brother The ...
# 15  gathered so thickly over me that I can see no ...
# 16  the Chairman "someone has to be responsible fo...
# 17  and on your arrival at Kingston to inquire for...
# 18  Sarah to Martha January 4 This being the anniv...
# 19  to the dimensions required. The nearest place ...
# 20  when reading the newspaper we expect to hear t...
# 21  Miss Fox know what I had asked. She told me to...
# 22  political feuds. Such quarrels provoke merely ...

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_keywords['Dominant_Topic'].value_counts()
topic_counts
# Out:
# 3     156
# 1     154
# 18    149
# 9     133
# 15    131
# 22    120
# 10    118
# 6     109
# 16    102
# 4      94
# 13     94
# 20     93
# 11     90
# 21     87
# 12     82
# 7      81
# 14     78
# 19     70
# 5      69
# 0      69
# 17     69
# 8      65
# 2      57
# Name: Dominant_Topic, dtype: int64

# %%
# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_contribution
# Out:
# 3     0.0687
# 1     0.0678
# 18    0.0656
# 9     0.0586
# 15    0.0577
# 22    0.0529
# 10    0.0520
# 6     0.0480
# 16    0.0449
# 4     0.0414
# 13    0.0414
# 20    0.0410
# 11    0.0396
# 21    0.0383
# 12    0.0361
# 7     0.0357
# 14    0.0344
# 19    0.0308
# 5     0.0304
# 0     0.0304
# 17    0.0304
# 8     0.0286
# 2     0.0251
# Name: Dominant_Topic, dtype: float64

# %%
# Topic Number and Keywords
topic_num_keywords = df_topic_keywords[['Dominant_Topic', 'Topic_Keywords']].drop_duplicates().sort_values(by = 'Dominant_Topic')
topic_num_keywords
# Out:
#      Dominant_Topic                                     Topic_Keywords
# 151               0  life, death, mind, manner, soul, nature, trial...
# 641               1  land, acre, year, farm, wheat, dollar, farmer,...
# 8                 2  body, air, food, night, head, arm, blood, pain...
# 81                3  child, letter, friend, heart, baby, kind, writ...
# 42                4  water, tea, pork, bread, thing, piece, box, po...
# 19                5  work, day, man, business, trade, hand, carpent...
# 6                 6  school, church, number, teacher, pupil, town, ...
# 0                 7  mind, order, call, man, companion, judge, hour...
# 152               8  time, day, week, thing, trouble, return, chang...
# 100               9  book, paper, copy, interest, letter, story, te...
# 1                10  man, mine, time, reason, number, distance, wag...
# 229              11  city, place, river, town, village, boat, inhab...
# 5                12  girl, eye, boy, character, woman, head, scene,...
# 60               13  winter, summer, tree, foot, horse, spring, woo...
# 304              14  country, money, pound, difficulty, account, pe...
# 7                15  family, year, friend, wife, husband, daughter,...
# 9                16  time, case, hospital, patient, doctor, train, ...
# 246              17  dollar, month, board, cent, day, wage, servant...
# 550              18  week, day, morning, bed, night, evening, clock...
# 35               19  place, house, people, person, time, building, ...
# 215              20  ship, company, captain, vessel, gold, passenge...
# 3                21  room, hand, door, table, hour, fear, stage, ge...
# 281              22  people, government, state, law, country, idea,...

# %%
topic_num_keywords.reset_index(drop=True, inplace=True)
topic_num_keywords
# Out:
#     Dominant_Topic                                     Topic_Keywords
# 0                0  life, death, mind, manner, soul, nature, trial...
# 1                1  land, acre, year, farm, wheat, dollar, farmer,...
# 2                2  body, air, food, night, head, arm, blood, pain...
# 3                3  child, letter, friend, heart, baby, kind, writ...
# 4                4  water, tea, pork, bread, thing, piece, box, po...
# 5                5  work, day, man, business, trade, hand, carpent...
# 6                6  school, church, number, teacher, pupil, town, ...
# 7                7  mind, order, call, man, companion, judge, hour...
# 8                8  time, day, week, thing, trouble, return, chang...
# 9                9  book, paper, copy, interest, letter, story, te...
# 10              10  man, mine, time, reason, number, distance, wag...
# 11              11  city, place, river, town, village, boat, inhab...
# 12              12  girl, eye, boy, character, woman, head, scene,...
# 13              13  winter, summer, tree, foot, horse, spring, woo...
# 14              14  country, money, pound, difficulty, account, pe...
# 15              15  family, year, friend, wife, husband, daughter,...
# 16              16  time, case, hospital, patient, doctor, train, ...
# 17              17  dollar, month, board, cent, day, wage, servant...
# 18              18  week, day, morning, bed, night, evening, clock...
# 19              19  place, house, people, person, time, building, ...
# 20              20  ship, company, captain, vessel, gold, passenge...
# 21              21  room, hand, door, table, hour, fear, stage, ge...
# 22              22  people, government, state, law, country, idea,...

# %%
# Reordering
# topic_num_keywords = topic_num_keywords.reindex([11,17,14,5,3,2,4,0,18,20,7,1,15,10,16,19,9,6,8,12,13])
# topic_num_keywords

# %%
# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts.rename('counts'), topic_contribution.rename('contribution')], axis=1).sort_values(by = 'Dominant_Topic')
df_dominant_topics
# Out:
#     Dominant_Topic                                     Topic_Keywords  counts  \
# 0                0  life, death, mind, manner, soul, nature, trial...      69
# 1                1  land, acre, year, farm, wheat, dollar, farmer,...     154
# 2                2  body, air, food, night, head, arm, blood, pain...      57
# 3                3  child, letter, friend, heart, baby, kind, writ...     156
# 4                4  water, tea, pork, bread, thing, piece, box, po...      94
# 5                5  work, day, man, business, trade, hand, carpent...      69
# 6                6  school, church, number, teacher, pupil, town, ...     109
# 7                7  mind, order, call, man, companion, judge, hour...      81
# 8                8  time, day, week, thing, trouble, return, chang...      65
# 9                9  book, paper, copy, interest, letter, story, te...     133
# 10              10  man, mine, time, reason, number, distance, wag...     118
# 11              11  city, place, river, town, village, boat, inhab...      90
# 12              12  girl, eye, boy, character, woman, head, scene,...      82
# 13              13  winter, summer, tree, foot, horse, spring, woo...      94
# 14              14  country, money, pound, difficulty, account, pe...      78
# 15              15  family, year, friend, wife, husband, daughter,...     131
# 16              16  time, case, hospital, patient, doctor, train, ...     102
# 17              17  dollar, month, board, cent, day, wage, servant...      69
# 18              18  week, day, morning, bed, night, evening, clock...     149
# 19              19  place, house, people, person, time, building, ...      70
# 20              20  ship, company, captain, vessel, gold, passenge...      93
# 21              21  room, hand, door, table, hour, fear, stage, ge...      87
# 22              22  people, government, state, law, country, idea,...     120
#
#     contribution
# 0         0.0304
# 1         0.0678
# 2         0.0251
# 3         0.0687
# 4         0.0414
# 5         0.0304
# 6         0.0480
# 7         0.0357
# 8         0.0286
# 9         0.0586
# 10        0.0520
# 11        0.0396
# 12        0.0361
# 13        0.0414
# 14        0.0344
# 15        0.0577
# 16        0.0449
# 17        0.0304
# 18        0.0656
# 19        0.0308
# 20        0.0410
# 21        0.0383
# 22        0.0529

# %%
df_dominant_topics.to_csv("20240411_PhD_TopicsLtrChkMAL23.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2270 entries, 0 to 2269
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   docID-AT          2270 non-null   int64
#  1   docauthorid       2270 non-null   object
#  2   docauthorname     2270 non-null   object
#  3   docid             2270 non-null   object
#  4   docyear           2235 non-null   float64
#  5   docmonth          2171 non-null   float64
#  6   authorgender      2270 non-null   object
#  7   agewriting        1536 non-null   float64
#  8   agedeath          1525 non-null   float64
#  9   relMin            1870 non-null   object
#  10  nationalOrigin    2266 non-null   object
#  11  authorLocation    2270 non-null   object
#  12  U                 2076 non-null   object
#  13  M                 2076 non-null   object
#  14  S                 2076 non-null   object
#  15  F                 2076 non-null   object
#  16  L                 2076 non-null   object
#  17  text              2270 non-null   object
#  18  sequence          2270 non-null   int64
#  19  scoreNeg          2270 non-null   float64
#  20  scorePos          2270 non-null   float64
#  21  scoreNeu          2270 non-null   float64
#  22  scoreCompound     2270 non-null   float64
#  23  totalTokens       2270 non-null   int64
#  24  uniqueTokens      2270 non-null   int64
#  25  lexicalDiversity  2270 non-null   float64
#  26  chunks            2270 non-null   int64
#  27  position          2270 non-null   float64
#  28  topicNumber       2270 non-null   int64
# dtypes: float64(10), int64(6), object(13)
# memory usage: 514.4+ KB

# %%
df.to_csv("20240411_PhD_Data4NER-LtrChk.csv")
