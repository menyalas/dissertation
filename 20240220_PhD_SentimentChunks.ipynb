# %% [markdown]
# # Sentiment Scores: Chunks

# %% [markdown]
# For system details and resources, see PhD_SystemCheck.ipynb and PhD_Modules.ipynb

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
import pandas as pd

# %%
import re

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1100,
    chunk_overlap=380,
    length_function=len,
    is_separator_regex=False,
)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sentimentAnalyzer = SentimentIntensityAnalyzer() #Initialize sentiment scorer

# %%
lettersCorpus = PlaintextCorpusReader('letters/cleaned/', '.*txt') #Define corpus
len(lettersCorpus.fileids()) #How many files
# Out:
# 576

# %%
sentimentChunk = pd.DataFrame(columns = ['chunk','docid','sequence','scoreNeg', 'scorePos', 'scoreNeu', 'scoreCompound']) # Create a new dataframe to hold sentences, letter id and compound scores
sentimentChunk.head()
# Out:
# Empty DataFrame
# Columns: [chunk, docid, sequence, scoreNeg, scorePos, scoreNeu, scoreCompound]
# Index: []

# %%
for fileid in lettersCorpus.fileids(): # For each file in the corpus
    text = lettersCorpus.raw(fileid) # Place the string into the object "text"
    chunks = text_splitter.split_text(text)
    sequence = 0 # Create a counter to keep track of sentence order
    for chunk in chunks: # For each sentence in this list  
        sequence +=1 # Counter updater
        scores = sentimentAnalyzer.polarity_scores(chunk) # Calculate sentiment scores
        new_row = pd.Series([chunk, fileid, sequence, scores['neg'], scores['pos'], scores['neu'], scores['compound']], index=["chunk", "docid", "sequence", "scoreNeg", "scorePos", "scoreNeu", "scoreCompound"])
        sentimentChunk = pd.concat([sentimentChunk, new_row.to_frame().T], ignore_index=True) # Populate a new row in the dataframe with the dictionary info
    print(fileid) # Show progress
# Out:
# S1019-D002.txt
# S1019-D004.txt
# S1019-D005.txt
# S1019-D006.txt
# S1019-D007.txt
# S1019-D008.txt
# S1019-D009.txt
# S1019-D010.txt
# S1019-D011.txt
# S1019-D012.txt
# S1019-D013.txt
# S1019-D014.txt
# S1019-D015.txt
# S1019-D016.txt
# S1019-D017.txt
# S1019-D018.txt
# S1019-D019.txt
# S1019-D020.txt
# S1019-D021.txt
# S1019-D022.txt
# S1019-D023.txt
# S1019-D024.txt
# S1019-D025.txt
# S1019-D026.txt
# S1019-D027.txt
# S1019-D028.txt
# S1019-D029.txt
# S1019-D030.txt
# S1019-D031.txt
# S1019-D032.txt
# S1019-D033.txt
# S1019-D034.txt
# S1019-D035.txt
# S1019-D036.txt
# S1019-D037.txt
# S1019-D038.txt
# S1019-D040.txt
# S1019-D041.txt
# S1019-D042.txt
# S1019-D043.txt
# S1019-D044.txt
# S1019-D045.txt
# S1019-D046.txt
# S1019-D047.txt
# S1019-D048.txt
# S1019-D049.txt
# S1019-D050.txt
# S1019-D051.txt
# S1019-D052.txt
# S1019-D053.txt
# S1019-D054.txt
# S1019-D055.txt
# S1019-D056.txt
# S1019-D057.txt
# S1019-D058.txt
# S2344-D038.txt
# S2344-D039.txt
# S2344-D040.txt
# S2344-D041.txt
# S2344-D042.txt
# S2344-D043.txt
# S2344-D044.txt
# S2344-D045.txt
# S2344-D046.txt
# S2344-D048.txt
# S2344-D049.txt
# S2344-D051.txt
# S2344-D052.txt
# S2344-D053.txt
# S2344-D055.txt
# S2344-D056.txt
# S2344-D057.txt
# S2344-D058.txt
# S2344-D059.txt
# S2344-D060.txt
# S2344-D061.txt
# S2344-D062.txt
# S2344-D063.txt
# S2344-D064.txt
# S2344-D065.txt
# S2344-D067.txt
# S2344-D068.txt
# S2344-D069.txt
# S2344-D070.txt
# S2344-D071.txt
# S2344-D072.txt
# S2344-D073.txt
# S2344-D074.txt
# S2344-D075.txt
# S2344-D076.txt
# S2344-D077.txt
# S2344-D079.txt
# S2344-D080.txt
# S2344-D081.txt
# S2344-D082.txt
# S2344-D083.txt
# S2344-D084.txt
# S2344-D085.txt
# S2344-D086.txt
# S2344-D087.txt
# S2344-D088.txt
# S2344-D089.txt
# S2344-D090.txt
# S2344-D091.txt
# S2344-D092.txt
# S2344-D093.txt
# S2344-D094.txt
# S2344-D095.txt
# S2344-D096.txt
# S2344-D097.txt
# S2344-D098.txt
# S2344-D100.txt
# S2344-D101.txt
# S2344-D102.txt
# S2344-D103.txt
# S2344-D104.txt
# S2344-D105.txt
# S2344-D106.txt
# S2344-D107.txt
# S2344-D108.txt
# S2344-D109.txt
# S2344-D110.txt
# S2344-D111.txt
# S2344-D112.txt
# S2344-D113.txt
# S2344-D114.txt
# S2344-D115.txt
# S2344-D116.txt
# S2344-D117.txt
# S2344-D118.txt
# S2344-D119.txt
# S2344-D120.txt
# S2344-D121.txt
# S2344-D122.txt
# S2344-D123.txt
# S2344-D124.txt
# S2344-D125.txt
# S2344-D126.txt
# S2344-D127.txt
# S2344-D128.txt
# S2344-D129.txt
# S2344-D130.txt
# S2344-D131.txt
# S2344-D132.txt
# S2344-D133.txt
# S2344-D134.txt
# S2344-D135.txt
# S2344-D136.txt
# S2344-D137.txt
# S2344-D138.txt
# S2344-D139.txt
# S2344-D140.txt
# S2344-D141.txt
# S2344-D142.txt
# S2344-D143.txt
# S2344-D144.txt
# S316-D004.txt
# S316-D031.txt
# S316-D037.txt
# S316-D040.txt
# S316-D049.txt
# S316-D050.txt
# S316-D052.txt
# S316-D053.txt
# S316-D054.txt
# S316-D055.txt
# S316-D058.txt
# S316-D061.txt
# S316-D064.txt
# S316-D071.txt
# S316-D072.txt
# S316-D079.txt
# S316-D132.txt
# S316-D137.txt
# S316-D163.txt
# S316-D180.txt
# S316-D182.txt
# S316-D189.txt
# S316-D193.txt
# S316-D202.txt
# S316-D204.txt
# S316-D205.txt
# S6210-D007.txt
# S6210-D009.txt
# S6210-D011.txt
# S6210-D014.txt
# S6210-D015.txt
# S6210-D016.txt
# S6210-D017.txt
# S6210-D018.txt
# S6210-D019.txt
# S6210-D020.txt
# S6210-D021.txt
# S6210-D022.txt
# S6210-D023.txt
# S6210-D024.txt
# S6210-D025.txt
# S6210-D026.txt
# S6210-D027.txt
# S6210-D028.txt
# S6210-D029.txt
# S6210-D030.txt
# S6210-D031.txt
# S6210-D032.txt
# S6210-D033.txt
# S6210-D034.txt
# S6210-D035.txt
# S6210-D036.txt
# S6210-D037.txt
# S6210-D038.txt
# S6210-D039.txt
# S6210-D040.txt
# S6210-D041.txt
# S6210-D042.txt
# S6210-D043.txt
# S6210-D044.txt
# S6210-D045.txt
# S6210-D046.txt
# S6210-D047.txt
# S6210-D048.txt
# S6210-D049.txt
# S6210-D050.txt
# S6210-D051.txt
# S6210-D052.txt
# S6210-D053.txt
# S6210-D054.txt
# S6210-D055.txt
# S6210-D056.txt
# S6210-D057.txt
# S6210-D058.txt
# S6210-D059.txt
# S6210-D060.txt
# S6210-D061.txt
# S6210-D062.txt
# S6210-D063.txt
# S6210-D064.txt
# S6210-D065.txt
# S6210-D066.txt
# S6210-D067.txt
# S6210-D068.txt
# S6210-D069.txt
# S6210-D070.txt
# S6210-D071.txt
# S6210-D072.txt
# S6210-D073.txt
# S6210-D074.txt
# S6210-D075.txt
# S6210-D076.txt
# S6210-D077.txt
# S6210-D078.txt
# S6210-D079.txt
# S6210-D080.txt
# S6210-D081.txt
# S6210-D082.txt
# S6210-D083.txt
# S6210-D084.txt
# S6210-D085.txt
# S6210-D086.txt
# S6210-D087.txt
# S6210-D088.txt
# S6210-D089.txt
# S6210-D090.txt
# S6210-D091.txt
# S6210-D092.txt
# S6210-D093.txt
# S6210-D095.txt
# S6210-D096.txt
# S6210-D097.txt
# S6210-D098.txt
# S6210-D099.txt
# S6210-D100.txt
# S6210-D101.txt
# S6210-D102.txt
# S6210-D103.txt
# S6210-D104.txt
# S6210-D105.txt
# S6210-D106.txt
# S6210-D107.txt
# S6210-D108.txt
# S6210-D109.txt
# S6210-D110.txt
# S6210-D111.txt
# S6210-D112.txt
# S6210-D113.txt
# S6210-D114.txt
# S6210-D115.txt
# S6210-D116.txt
# S6210-D117.txt
# S6210-D118.txt
# S6210-D119.txt
# S6210-D121.txt
# S6210-D122.txt
# S6210-D123.txt
# S6210-D124.txt
# S6210-D125.txt
# S6210-D126.txt
# S6210-D127.txt
# S6210-D128.txt
# S6210-D129.txt
# S6210-D130.txt
# S6210-D131.txt
# S6210-D132.txt
# S6210-D133.txt
# S6210-D134.txt
# S6210-D135.txt
# S6210-D136.txt
# S6210-D137.txt
# S6210-D138.txt
# S6210-D139.txt
# S6210-D140.txt
# S6210-D141.txt
# S6210-D142.txt
# S6210-D143.txt
# S6210-D144.txt
# S6210-D145.txt
# S6210-D146.txt
# S6210-D147.txt
# S6210-D148.txt
# S6210-D149.txt
# S6210-D150.txt
# S6210-D151.txt
# S6210-D152.txt
# S6210-D153.txt
# S6210-D154.txt
# S6210-D155.txt
# S6210-D156.txt
# S6210-D157.txt
# S6210-D158.txt
# S6210-D159.txt
# S6210-D160.txt
# S6210-D161.txt
# S6210-D162.txt
# S6210-D163.txt
# S6210-D164.txt
# S6210-D165.txt
# S6210-D166.txt
# S6210-D167.txt
# S6210-D168.txt
# S6210-D169.txt
# S6210-D170.txt
# S6210-D171.txt
# S6210-D172.txt
# S6210-D173.txt
# S6210-D174.txt
# S6210-D175.txt
# S6210-D176.txt
# S6210-D177.txt
# S6210-D178.txt
# S6210-D179.txt
# S6210-D180.txt
# S6210-D181.txt
# S6210-D182.txt
# S6210-D183.txt
# S6210-D184.txt
# S6210-D185.txt
# S6210-D186.txt
# S6210-D187.txt
# S6210-D188.txt
# S6210-D189.txt
# S6210-D190.txt
# S6210-D191.txt
# S6210-D192.txt
# S6210-D193.txt
# S6210-D194.txt
# S6210-D195.txt
# S6210-D196.txt
# S6210-D197.txt
# S6210-D198.txt
# S6210-D200.txt
# S6210-D201.txt
# S6210-D202.txt
# S6210-D203.txt
# S6210-D204.txt
# S6210-D205.txt
# S6210-D206.txt
# S6210-D207.txt
# S6210-D208.txt
# S6210-D209.txt
# S6210-D210.txt
# S6210-D211.txt
# S6210-D212.txt
# S6210-D213.txt
# S6210-D214.txt
# S6210-D215.txt
# S6210-D216.txt
# S6210-D217.txt
# S6210-D219.txt
# S6210-D220.txt
# S6210-D221.txt
# S6210-D222.txt
# S6210-D223.txt
# S6210-D224.txt
# S6210-D225.txt
# S6210-D226.txt
# S6210-D227.txt
# S6210-D228.txt
# S6210-D229.txt
# S6210-D230.txt
# S6210-D231.txt
# S6210-D232.txt
# S6210-D233.txt
# S6210-D234.txt
# S6210-D235.txt
# S6210-D236.txt
# S6210-D237.txt
# S6210-D238.txt
# S6210-D239.txt
# S8557-D007.txt
# S9110-D004.txt
# S9635-D006.txt
# S9635-D010.txt
# S9635-D014.txt
# S9635-D015.txt
# S9635-D016.txt
# S9635-D017.txt
# S9635-D018.txt
# S9635-D019.txt
# S9635-D020.txt
# S9635-D023.txt
# S9635-D024.txt
# S9635-D025.txt
# S9635-D026.txt
# S9635-D027.txt
# S9635-D028.txt
# S9635-D029.txt
# S9635-D030.txt
# S9635-D031.txt
# S9635-D032.txt
# S9635-D034.txt
# S9635-D035.txt
# S9635-D036.txt
# S9635-D037.txt
# S9635-D038.txt
# S9635-D039.txt
# S9635-D042.txt
# S9635-D043.txt
# S9635-D044.txt
# S9635-D045.txt
# S9635-D046.txt
# S9635-D047.txt
# S9635-D048.txt
# S9635-D049.txt
# S9635-D050.txt
# S9635-D051.txt
# S9635-D052.txt
# S9635-D053.txt
# S9819-D013.txt
# S9819-D014.txt
# S9819-D015.txt
# S9819-D016.txt
# S9819-D017.txt
# S9819-D018.txt
# S9819-D019.txt
# S9819-D020.txt
# S9819-D021.txt
# S9819-D022.txt
# S9819-D023.txt
# S9819-D024.txt
# S9819-D025.txt
# S9819-D026.txt
# S9819-D027.txt
# S9819-D028.txt
# S9828-D002.txt
# S9828-D003.txt
# S9828-D004.txt
# S9828-D005.txt
# S9828-D006.txt
# S9828-D007.txt
# S9828-D008.txt
# S9828-D009.txt
# S9828-D010.txt
# S9828-D011.txt
# S9828-D012.txt
# S9828-D013.txt
# S9828-D014.txt
# S9828-D015.txt
# S9828-D016.txt
# S9828-D017.txt
# S9828-D018.txt
# S9828-D019.txt
# S9828-D020.txt
# S9828-D021.txt
# S9828-D022.txt
# S9828-D023.txt
# S9828-D024.txt
# S9828-D025.txt
# S9828-D026.txt
# S9828-D027.txt
# S9845-D002.txt
# S9845-D003.txt
# S9845-D004.txt
# S9845-D005.txt
# S9845-D006.txt
# S9845-D007.txt
# S9845-D008.txt
# S9845-D009.txt
# S9845-D010.txt
# S9865-D009.txt
# S9865-D010.txt
# S9865-D011.txt
# S9865-D012.txt
# S9865-D013.txt
# S9865-D014.txt
# S9865-D015.txt
# S9865-D016.txt
# S9865-D017.txt
# S9865-D018.txt
# S9865-D019.txt
# S9865-D020.txt
# S9865-D021.txt
# S9865-D022.txt
# S9865-D023.txt
# S9865-D024.txt
# S9865-D025.txt
# S9865-D026.txt
# S9865-D027.txt
# S9865-D028.txt
# S9865-D029.txt
# S9865-D030.txt
# S9865-D031.txt
# S9865-D032.txt
# S9865-D033.txt
# S9865-D034.txt
# S9865-D035.txt
# S9865-D036.txt
# S9865-D037.txt
# S9865-D038.txt
# S9865-D039.txt
# S9865-D040.txt
# S9865-D045.txt
# S9865-D046.txt
# S9865-D047.txt
# S9865-D054.txt
# S9865-D055.txt
# S9865-D056.txt
# S9865-D057.txt
# S9865-D058.txt
# S9865-D059.txt
# S9865-D060.txt
# S9865-D061.txt
# S9865-D072.txt
# S9865-D073.txt
# S9865-D078.txt
# S9873-D013.txt
# S9873-D014.txt
# S9873-D015.txt
# S9873-D017.txt
# S9873-D018.txt
# S9873-D019.txt
# S9873-D020.txt
# S9873-D021.txt
# S9908-D030.txt
# S9908-D031.txt
# S9908-D032.txt
# S9908-D033.txt
# S9908-D034.txt
# S9908-D035.txt
# S9908-D036.txt
# S9908-D037.txt
# S9908-D038.txt
# S9908-D039.txt
# S9912-D002.txt
# S9912-D003.txt
# S9912-D004.txt
# S9913-D003.txt
# S9913-D004.txt
# S9913-D006.txt
# S9913-D015.txt
# S9913-D016.txt
# S9957-D012.txt
# S9957-D013.txt
# S9957-D014.txt
# S9957-D015.txt
# S9974-D008.txt
# S9974-D010.txt
# S9974-D029.txt

# %%
sentimentChunk
# Out:
#                                                   chunk           docid  \
# 0     TRINIDAD On Train from Steubenville, Ohio, to ...  S1019-D002.txt
# 1     Josephine. This letter thrilled us both. I was...  S1019-D002.txt
# 2     them at two-thirty without one word of goodbye...  S1019-D002.txt
# 3     This in substance was their conversation with ...  S1019-D002.txt
# 4     three o'clock A M the baggage checker came thr...  S1019-D002.txt
# ...                                                 ...             ...
# 3780  by Chinamen are now sold in this market quite ...  S9974-D029.txt
# 3781  high living was possible. To augment this prol...  S9974-D029.txt
# 3782  or a manufactury without steam. The Chinese ar...  S9974-D029.txt
# 3783  enough. The times are hard; there is much suff...  S9974-D029.txt
# 3784  of government bonds and other property from ta...  S9974-D029.txt
#
#      sequence scoreNeg scorePos scoreNeu scoreCompound
# 0           1    0.053    0.119    0.827        0.9425
# 1           2     0.05    0.092    0.859        0.8625
# 2           3    0.037     0.08    0.883        0.6977
# 3           4    0.056    0.132    0.812        0.9451
# 4           5    0.059    0.148    0.793        0.9509
# ...       ...      ...      ...      ...           ...
# 3780        7    0.074    0.128    0.798        0.9186
# 3781        8    0.104     0.04    0.856       -0.8997
# 3782        9    0.146    0.018    0.836       -0.9746
# 3783       10    0.132    0.052    0.815       -0.9349
# 3784       11    0.084      0.1    0.816          0.34
#
# [3785 rows x 7 columns]

# %%
# Remove the .txt from the file name
sentimentChunk['docid'] = sentimentChunk['docid'].str.replace(r'.txt', '', regex=True)
sentimentChunk
# Out:
#                                                   chunk       docid sequence  \
# 0     TRINIDAD On Train from Steubenville, Ohio, to ...  S1019-D002        1
# 1     Josephine. This letter thrilled us both. I was...  S1019-D002        2
# 2     them at two-thirty without one word of goodbye...  S1019-D002        3
# 3     This in substance was their conversation with ...  S1019-D002        4
# 4     three o'clock A M the baggage checker came thr...  S1019-D002        5
# ...                                                 ...         ...      ...
# 3780  by Chinamen are now sold in this market quite ...  S9974-D029        7
# 3781  high living was possible. To augment this prol...  S9974-D029        8
# 3782  or a manufactury without steam. The Chinese ar...  S9974-D029        9
# 3783  enough. The times are hard; there is much suff...  S9974-D029       10
# 3784  of government bonds and other property from ta...  S9974-D029       11
#
#      scoreNeg scorePos scoreNeu scoreCompound
# 0       0.053    0.119    0.827        0.9425
# 1        0.05    0.092    0.859        0.8625
# 2       0.037     0.08    0.883        0.6977
# 3       0.056    0.132    0.812        0.9451
# 4       0.059    0.148    0.793        0.9509
# ...       ...      ...      ...           ...
# 3780    0.074    0.128    0.798        0.9186
# 3781    0.104     0.04    0.856       -0.8997
# 3782    0.146    0.018    0.836       -0.9746
# 3783    0.132    0.052    0.815       -0.9349
# 3784    0.084      0.1    0.816          0.34
#
# [3785 rows x 7 columns]

# %%
# Add a column "chunks" showing total number of sentences in letter
sentimentChunk['chunks'] = sentimentChunk.groupby('docid')['sequence'].transform('max')
sentimentChunk
# Out:
#                                                   chunk       docid sequence  \
# 0     TRINIDAD On Train from Steubenville, Ohio, to ...  S1019-D002        1
# 1     Josephine. This letter thrilled us both. I was...  S1019-D002        2
# 2     them at two-thirty without one word of goodbye...  S1019-D002        3
# 3     This in substance was their conversation with ...  S1019-D002        4
# 4     three o'clock A M the baggage checker came thr...  S1019-D002        5
# ...                                                 ...         ...      ...
# 3780  by Chinamen are now sold in this market quite ...  S9974-D029        7
# 3781  high living was possible. To augment this prol...  S9974-D029        8
# 3782  or a manufactury without steam. The Chinese ar...  S9974-D029        9
# 3783  enough. The times are hard; there is much suff...  S9974-D029       10
# 3784  of government bonds and other property from ta...  S9974-D029       11
#
#      scoreNeg scorePos scoreNeu scoreCompound chunks
# 0       0.053    0.119    0.827        0.9425     15
# 1        0.05    0.092    0.859        0.8625     15
# 2       0.037     0.08    0.883        0.6977     15
# 3       0.056    0.132    0.812        0.9451     15
# 4       0.059    0.148    0.793        0.9509     15
# ...       ...      ...      ...           ...    ...
# 3780    0.074    0.128    0.798        0.9186     11
# 3781    0.104     0.04    0.856       -0.8997     11
# 3782    0.146    0.018    0.836       -0.9746     11
# 3783    0.132    0.052    0.815       -0.9349     11
# 3784    0.084      0.1    0.816          0.34     11
#
# [3785 rows x 8 columns]

# %%
# Add a column "Position" showing the location of the chunk relative to the whole 
# That is, how far through the letter does the chunk appear?
sentimentChunk['position'] = sentimentChunk['sequence'] / sentimentChunk['chunks']
sentimentChunk
# Out:
#                                                   chunk       docid sequence  \
# 0     TRINIDAD On Train from Steubenville, Ohio, to ...  S1019-D002        1
# 1     Josephine. This letter thrilled us both. I was...  S1019-D002        2
# 2     them at two-thirty without one word of goodbye...  S1019-D002        3
# 3     This in substance was their conversation with ...  S1019-D002        4
# 4     three o'clock A M the baggage checker came thr...  S1019-D002        5
# ...                                                 ...         ...      ...
# 3780  by Chinamen are now sold in this market quite ...  S9974-D029        7
# 3781  high living was possible. To augment this prol...  S9974-D029        8
# 3782  or a manufactury without steam. The Chinese ar...  S9974-D029        9
# 3783  enough. The times are hard; there is much suff...  S9974-D029       10
# 3784  of government bonds and other property from ta...  S9974-D029       11
#
#      scoreNeg scorePos scoreNeu scoreCompound chunks  position
# 0       0.053    0.119    0.827        0.9425     15  0.066667
# 1        0.05    0.092    0.859        0.8625     15  0.133333
# 2       0.037     0.08    0.883        0.6977     15       0.2
# 3       0.056    0.132    0.812        0.9451     15  0.266667
# 4       0.059    0.148    0.793        0.9509     15  0.333333
# ...       ...      ...      ...           ...    ...       ...
# 3780    0.074    0.128    0.798        0.9186     11  0.636364
# 3781    0.104     0.04    0.856       -0.8997     11  0.727273
# 3782    0.146    0.018    0.836       -0.9746     11  0.818182
# 3783    0.132    0.052    0.815       -0.9349     11  0.909091
# 3784    0.084      0.1    0.816          0.34     11       1.0
#
# [3785 rows x 9 columns]

# %%
sentimentChunk.to_csv('20240220_PhD_SentimentChunk.csv', index = True)
