# %% [markdown]
# ## Merge topic labels to letter dataframe

# %%
import pickle
import gensim
from gensim import models
import gensim.corpora as corpora
import pandas as pd
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)
from pprint import pprint

# %% [markdown]
# ## Get Resources

# %%
# Lemmanized text
with open("20240220_PhD_LtrLem-NV.txt", "rb") as fp:   # Unpickling
    data_lemmatized = pickle.load(fp)

# %%
# Load saved mallet
lda_mallet = gensim.models.wrappers.LdaMallet.load("20240221_PhD_TopicLtrMAL14")
# Convert to LDA
ldamodel = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(lda_mallet)

# %%
pprint(sorted(ldamodel.print_topics(num_words=10)))
# Out:
# [(0,
#   '0.032*"time" + 0.020*"people" + 0.017*"day" + 0.016*"give" + 0.016*"person" '
#   '+ 0.014*"manner" + 0.014*"order" + 0.014*"case" + 0.014*"return" + '
#   '0.014*"child"'),
#  (1,
#   '0.039*"place" + 0.026*"town" + 0.024*"day" + 0.023*"walk" + 0.020*"house" + '
#   '0.016*"travel" + 0.015*"remain" + 0.015*"return" + 0.015*"reach" + '
#   '0.015*"call"'),
#  (2,
#   '0.052*"land" + 0.046*"country" + 0.027*"acre" + 0.027*"farm" + '
#   '0.017*"dollar" + 0.014*"farmer" + 0.014*"sell" + 0.014*"pound" + '
#   '0.014*"wood" + 0.013*"price"'),
#  (3,
#   '0.048*"week" + 0.036*"child" + 0.029*"day" + 0.028*"critchlow" + '
#   '0.019*"stay" + 0.019*"evening" + 0.018*"feel" + 0.015*"today" + 0.014*"boy" '
#   '+ 0.014*"morning"'),
#  (4,
#   '0.065*"year" + 0.044*"letter" + 0.036*"send" + 0.033*"family" + '
#   '0.032*"brother" + 0.030*"live" + 0.025*"hear" + 0.021*"money" + '
#   '0.021*"friend" + 0.021*"write"'),
#  (5,
#   '0.088*"sister" + 0.018*"school" + 0.015*"man" + 0.014*"room" + '
#   '0.012*"visit" + 0.011*"mother" + 0.011*"give" + 0.010*"speak" + '
#   '0.009*"hospital" + 0.008*"patient"'),
#  (6,
#   '0.031*"write" + 0.031*"book" + 0.026*"send" + 0.020*"work" + 0.016*"copy" + '
#   '0.016*"receive" + 0.015*"paper" + 0.014*"read" + 0.012*"pleasure" + '
#   '0.011*"publish"'),
#  (7,
#   '0.023*"people" + 0.021*"state" + 0.017*"year" + 0.017*"city" + '
#   '0.016*"world" + 0.015*"dollar" + 0.013*"employment" + 0.011*"business" + '
#   '0.011*"find" + 0.011*"wage"'),
#  (8,
#   '0.026*"day" + 0.023*"ship" + 0.021*"water" + 0.013*"bed" + '
#   '0.013*"passenger" + 0.013*"pass" + 0.012*"wind" + 0.012*"sea" + '
#   '0.012*"boat" + 0.012*"night"'),
#  (9,
#   '0.024*"place" + 0.020*"year" + 0.019*"church" + 0.016*"country" + '
#   '0.015*"settlement" + 0.014*"settle" + 0.013*"land" + 0.013*"government" + '
#   '0.012*"number" + 0.012*"form"'),
#  (10,
#   '0.071*"work" + 0.037*"day" + 0.036*"give" + 0.028*"time" + 0.025*"place" + '
#   '0.024*"money" + 0.023*"pay" + 0.023*"month" + 0.017*"man" + 0.014*"find"'),
#  (11,
#   '0.035*"letter" + 0.032*"write" + 0.027*"feel" + 0.027*"child" + '
#   '0.022*"hear" + 0.021*"mother" + 0.021*"send" + 0.020*"give" + 0.019*"girl" '
#   '+ 0.018*"kind"'),
#  (12,
#   '0.016*"call" + 0.016*"man" + 0.014*"law" + 0.014*"country" + 0.009*"head" + '
#   '0.009*"enemy" + 0.008*"crime" + 0.008*"government" + 0.008*"nation" + '
#   '0.007*"war"'),
#  (13,
#   '0.031*"hand" + 0.029*"life" + 0.020*"time" + 0.020*"give" + 0.019*"friend" '
#   '+ 0.019*"mind" + 0.018*"eye" + 0.015*"heart" + 0.013*"hold" + '
#   '0.012*"change"')]

# %%
# Metadata
df = pd.read_csv("20240220_PhD_Data4TopicModel-Letter.csv") 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        576 non-null    int64
#  1   docauthorid       576 non-null    object
#  2   docauthorname     576 non-null    object
#  3   docid             576 non-null    object
#  4   sourcetitle       576 non-null    object
#  5   docyear           573 non-null    float64
#  6   docmonth          519 non-null    float64
#  7   docday            474 non-null    float64
#  8   authorgender      576 non-null    object
#  9   agewriting        460 non-null    float64
#  10  birthyear         463 non-null    float64
#  11  deathyear         449 non-null    float64
#  12  religionNew       450 non-null    object
#  13  relMin            474 non-null    object
#  14  nationalOrigin    575 non-null    object
#  15  britishEmpire_EU  573 non-null    object
#  16  translated        576 non-null    bool
#  17  authorLocation    576 non-null    object
#  18  socialClass       513 non-null    object
#  19  A                 513 non-null    object
#  20  I                 513 non-null    object
#  21  CCP               513 non-null    object
#  22  Unknown           513 non-null    object
#  23  wageLabour        513 non-null    object
#  24  publicLetter      16 non-null     object
#  25  text              576 non-null    object
#  26  scoreNeg          576 non-null    float64
#  27  scorePos          576 non-null    float64
#  28  scoreNeu          576 non-null    float64
#  29  scoreCompound     576 non-null    float64
# dtypes: bool(1), float64(10), int64(1), object(18)
# memory usage: 131.2+ KB

# %%
df.head()
# Out:
#    Unnamed: 0 docauthorid                       docauthorname       docid  \
# 0           1  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D002
# 1           2  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D004
# 2           3  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D005
# 3           4  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D006
# 4           5  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D007
#
#                         sourcetitle  docyear  docmonth  docday authorgender  \
# 0  At the End of the Santa Fe Trail   1872.0      11.0    30.0            F
# 1  At the End of the Santa Fe Trail   1872.0      12.0     6.0            F
# 2  At the End of the Santa Fe Trail   1872.0      12.0    10.0            F
# 3  At the End of the Santa Fe Trail   1872.0      12.0    21.0            F
# 4  At the End of the Santa Fe Trail   1873.0       3.0     1.0            F
#
#    agewriting  ...      I   CCP Unknown wageLabour publicLetter  \
# 0        22.0  ...  False  True   False      False          NaN
# 1        22.0  ...  False  True   False      False          NaN
# 2        22.0  ...  False  True   False      False          NaN
# 3        22.0  ...  False  True   False      False          NaN
# 4        23.0  ...  False  True   False      False          NaN
#
#                                                 text  scoreNeg scorePos  \
# 0   TRINIDAD On Train from Steubenville, Ohio, to...     0.051    0.131
# 1   Kansas City, Dec 6, 1872. Number one! Number ...     0.055    0.111
# 2   Trinidad, December 10, 1872. My dearest dear:...     0.056    0.101
# 3   December 21. Rumor is loud in predicting an a...     0.061    0.099
# 4   March 1, 1873. My Dear Sister Justina: It is ...     0.071    0.081
#
#   scoreNeu scoreCompound
# 0    0.818        0.9994
# 1    0.834        0.9993
# 2    0.843        0.9987
# 3    0.840        0.9981
# 4    0.848        0.9670
#
# [5 rows x 30 columns]

# %%
# Change column name to "docID-AT"
df = df.rename(columns={'Unnamed: 0':'docID-AT'})
df
# Out:
#      docID-AT docauthorid                       docauthorname       docid  \
# 0           1  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D002
# 1           2  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D004
# 2           3  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D005
# 3           4  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D006
# 4           5  per0001043  Segale, Sister Blandina, 1850-1941  S1019-D007
# ..        ...         ...                                 ...         ...
# 571       572  per0022894   Hutchings, James Mason, 1820-1902  S9957-D014
# 572       573  per0022894   Hutchings, James Mason, 1820-1902  S9957-D015
# 573       574  per0036192              Thorpe, John, fl. 1828  S9974-D008
# 574       575  per0036196               Downe, John, fl. 1830  S9974-D010
# 575       576  per0036238         Ling, Kwang Chang, fl. 1878  S9974-D029
#
#                                            sourcetitle  docyear  docmonth  \
# 0                     At the End of the Santa Fe Trail   1872.0      11.0
# 1                     At the End of the Santa Fe Trail   1872.0      12.0
# 2                     At the End of the Santa Fe Trail   1872.0      12.0
# 3                     At the End of the Santa Fe Trail   1872.0      12.0
# 4                     At the End of the Santa Fe Trail   1873.0       3.0
# ..                                                 ...      ...       ...
# 571  Seeking the Elephant: James Mason Hutching's J...   1850.0       3.0
# 572  Seeking the Elephant: James Mason Hutching's J...   1851.0       4.0
# 573  America's Immigrants: Adventures in Eyewitness...   1828.0       NaN
# 574  America's Immigrants: Adventures in Eyewitness...   1830.0       8.0
# 575  America's Immigrants: Adventures in Eyewitness...   1878.0       8.0
#
#      docday authorgender  agewriting  ...      I    CCP Unknown wageLabour  \
# 0      30.0            F        22.0  ...  False   True   False      False
# 1       6.0            F        22.0  ...  False   True   False      False
# 2      10.0            F        22.0  ...  False   True   False      False
# 3      21.0            F        22.0  ...  False   True   False      False
# 4       1.0            F        23.0  ...  False   True   False      False
# ..      ...          ...         ...  ...    ...    ...     ...        ...
# 571    22.0            M        30.0  ...   True   True   False      False
# 572     4.0            M        31.0  ...   True   True   False      False
# 573     NaN            M         NaN  ...    NaN    NaN     NaN        NaN
# 574    12.0            M         NaN  ...   True  False   False      False
# 575     2.0            M         NaN  ...    NaN    NaN     NaN        NaN
#
#     publicLetter                                               text  scoreNeg  \
# 0            NaN   TRINIDAD On Train from Steubenville, Ohio, to...     0.051
# 1            NaN   Kansas City, Dec 6, 1872. Number one! Number ...     0.055
# 2            NaN   Trinidad, December 10, 1872. My dearest dear:...     0.056
# 3            NaN   December 21. Rumor is loud in predicting an a...     0.061
# 4            NaN   March 1, 1873. My Dear Sister Justina: It is ...     0.071
# ..           ...                                                ...       ...
utes when again I rang the doorbell. Sister Anthony came. "Why, child, where did you come from; how did you get here? I'm sure you are cold." I said I came from Steubenville. "Oh, yes! dear Father Bigelow died there. He was good to this hospital. Last year he sent a barge of coal to us." I said he was good to anyone in need. He died possessed of three dollars and fifty cents. His hand was always open to any kind of distress. I did not mention to Sister Anthony that I walked from the Little Miami Station. After Mass, breakfast and miles of sympathy and "God Bless You" from the Sisters at the Good Samaritan, one of the nurses accompanied me to Fifth and Vin ...

# %% [markdown]
# # Create Functions & Objects

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
def format_topics(ldamodel=ldamodel, corpus=corpus, texts=texts):
    # Init output
    topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                topics_df = topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    topics_df = pd.concat([topics_df, contents], axis=1)
    return(topics_df)

# %%
# Check the topic for the first 10 rows. 
df_topic_keywords = format_topics(ldamodel=ldamodel, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head()
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0               5              0.3080
# 1            1               1              0.3901
# 2            2               1              0.3827
# 3            3               5              0.3496
# 4            4               1              0.3119
#
#                                             Keywords  \
# 0  sister, school, man, room, visit, mother, give...
# 1  place, town, day, walk, house, travel, remain,...
# 2  place, town, day, walk, house, travel, remain,...
# 3  sister, school, man, room, visit, mother, give...
# 4  place, town, day, walk, house, travel, remain,...
#
#                                                 Text
# 0   TRINIDAD On Train from Steubenville, Ohio, to...
# 1   Kansas City, Dec 6, 1872. Number one! Number ...
# 2   Trinidad, December 10, 1872. My dearest dear:...
# 3   December 21. Rumor is loud in predicting an a...
# 4   March 1, 1873. My Dear Sister Justina: It is ...

# %%
map_Text_topicNumber = {}

# %%
for index, item in enumerate(data):
    topic_dist = ldamodel.get_document_topics(corpus[index])

    # topic_dist is a list of tuples: each tuple has a topic number with its corresponding proportion
    sorted_topic_dist = sorted(topic_dist, key=lambda x: (x[1]), reverse=True) # Sort it in descending order
    
    # Pick the top one:
    topic_number = sorted_topic_dist[0][0]
    map_Text_topicNumber[item] = topic_number

# %%
# View the first key value pair in dictionary (text, label)
dict(list(map_Text_topicNumber.items())[0:1])
# Out:
# 3   S1019-D006  per0001043   December 21. Rumor is loud in predicting an a...
# 4   S1019-D007  per0001043   March 1, 1873. My Dear Sister Justina: It is ...
# 5   S1019-D008  per0001043   July, 1873. Dear Sister Justina: The last tim...
# 6   S1019-D009  per0001043   September, 1873. Dearest Sister Justina: Our ...
# 7   S1019-D010  per0001043   Dear Sister Justina: June 30, 1874. It is nea...
# 8   S1019-D011  per0001043   November 14. Three of my senior pupils have g...
# 9   S1019-D012  per0001043   June, 1876. Dear Sister Justina: To-day I ask...
# 10  S1019-D013  per0001043   September, 1876. The pupils and myself will h...
#
#     topicNumber
# 0             5
# 1             1
# 2             1
# 3             5
# 4             1
# 5             5
# 6             5
# 7             5
# 8             5
# 9             5
# 10            5

# %%
# Group top 5 sentences under each topic
topics_sorteddf_mallet = pd.DataFrame()

topics_outdf_grpd = df_topic_keywords.groupby('Dominant_Topic')

for i, grp in topics_outdf_grpd:
    topics_sorteddf_mallet = pd.concat([topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
topics_sorteddf_mallet
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0           0              0.5147
# 1           1              0.3901
# 2           2              0.5737
# 3           3              0.3939
# 4           4              0.4449
# 5           5              0.4750
# 6           6              0.4868
# 7           7              0.4524
# 8           8              0.6604
# 9           9              0.6310
# 10         10              0.5128
# 11         11              0.3901
# 12         12              0.5707
# 13         13              0.3813
#
#                                              Keywords  \
# 0   time, people, day, give, person, manner, order...
# 1   place, town, day, walk, house, travel, remain,...
# 2   land, country, acre, farm, dollar, farmer, sel...
# 3   week, child, day, critchlow, stay, evening, fe...
# 4   year, letter, send, family, brother, live, hea...
# 5   sister, school, man, room, visit, mother, give...
# 6   write, book, send, work, copy, receive, paper,...
# 7   people, state, year, city, world, dollar, empl...
# 8   day, ship, water, bed, passenger, pass, wind, ...
# 9   place, year, church, country, settlement, sett...
# 10  work, day, give, time, place, money, pay, mont...
# 11  letter, write, feel, child, hear, mother, send...
# 12  call, man, law, country, head, enemy, crime, g...
# 13  hand, life, time, give, friend, mind, eye, hea...
#
#                                                  Text
# 0    Having, in my former letters, obeyed the prin...
# 1    Kansas City, Dec 6, 1872. Number one! Number ...
# 2    Extract of a letter from Mr Birkbeck to his s...
# 3    Sarah To Martha January 21, 1857 I cannot tel...
# 4    January 4th 1860 Dear Brother, I am spared th...
# 5    November 14. Three of my senior pupils have g...
# 6    78 To Richard Bentley Belleville April 24 / 6...
# 7    Wisconsin, United States of America, January ...
# 8    Our residence on the banks of Newfoundland co...
# 9    For more than a year I preached in the large ...
# 10  November 10, 1895 YOU will I am sure be surpri...
# 11   134 To Catharine Parr Traill 17 Wilton Cresce...
# 12   THE first visit or visitation of our English ...
# 13   68 To Richard Bentley May 2, 1858 Belleville ...

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_keywords['Dominant_Topic'].value_counts()
topic_counts
# Out:
# 3     171
# 2      79
# 11     71
# 5      51
# 6      41
# 4      36
# 8      28
# 9      25
# 10     16
# 12     15
# 1      14
# 7      14
# 0       8
# 13      7
# Name: Dominant_Topic, dtype: int64

# %%
# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_contribution
# Out:
# 3     0.2969
# 2     0.1372
# 11    0.1233
# 5     0.0885
# 6     0.0712
# 4     0.0625
# 8     0.0486
# 9     0.0434
# 10    0.0278
# 12    0.0260
# 1     0.0243
# 7     0.0243
# 0     0.0139
# 13    0.0122
# Name: Dominant_Topic, dtype: float64

# %%
# Topic Number and Keywords
topic_num_keywords = df_topic_keywords[['Dominant_Topic', 'Topic_Keywords']].drop_duplicates().sort_values(by = 'Dominant_Topic')
topic_num_keywords
# Out:
#      Dominant_Topic                                     Topic_Keywords
# 89                0  time, people, day, give, person, manner, order...
# 1                 1  place, town, day, walk, house, travel, remain,...
# 83                2  land, country, acre, farm, dollar, farmer, sel...
# 185               3  week, child, day, critchlow, stay, evening, fe...
# 71                4  year, letter, send, family, brother, live, hea...
# 0                 5  sister, school, man, room, visit, mother, give...
# 56                6  write, book, send, work, copy, receive, paper,...
# 158               7  people, state, year, city, world, dollar, empl...
# 84                8  day, ship, water, bed, passenger, pass, wind, ...
# 159               9  place, year, church, country, settlement, sett...
# 111              10  work, day, give, time, place, money, pay, mont...
# 75               11  letter, write, feel, child, hear, mother, send...
# 161              12  call, man, law, country, head, enemy, crime, g...
# 55               13  hand, life, time, give, friend, mind, eye, hea...

# %%
topic_num_keywords.reset_index(drop=True, inplace=True)
topic_num_keywords
# Out:
#     Dominant_Topic                                     Topic_Keywords
# 0                0  time, people, day, give, person, manner, order...
# 1                1  place, town, day, walk, house, travel, remain,...
# 2                2  land, country, acre, farm, dollar, farmer, sel...
# 3                3  week, child, day, critchlow, stay, evening, fe...
# 4                4  year, letter, send, family, brother, live, hea...
# 5                5  sister, school, man, room, visit, mother, give...
# 6                6  write, book, send, work, copy, receive, paper,...
# 7                7  people, state, year, city, world, dollar, empl...
# 8                8  day, ship, water, bed, passenger, pass, wind, ...
# 9                9  place, year, church, country, settlement, sett...
# 10              10  work, day, give, time, place, money, pay, mont...
# 11              11  letter, write, feel, child, hear, mother, send...
# 12              12  call, man, law, country, head, enemy, crime, g...
# 13              13  hand, life, time, give, friend, mind, eye, hea...

# %%
# Reordering
# topic_num_keywords = topic_num_keywords.reindex([11,17,14,5,3,2,4,0,18,20,7,1,15,10,16,19,9,6,8,12,13])
# topic_num_keywords
# Out:
#     Dominant_Topic                                     Topic_Keywords
# 11            11.0  week, day, weather, boy, baby, morning, doctor...
# 17            17.0  thing, time, people, year, lot, house, uncle, ...
# 14            14.0  land, country, acre, farm, year, farmer, wheat...
# 5              5.0  book, paper, work, dear, copy, friend, world, ...
# 3              3.0  letter, brother, time, wife, health, news, mai...
# 2              2.0  sister, man, room, hospital, mother, place, pa...
# 4              4.0  child, school, mother, boy, time, teacher, par...
# 0              0.0  day, morning, ship, hour, sea, night, time, wi...
# 18            18.0  year, wife, money, time, care, interest, husba...
# 20            20.0  work, dollar, month, day, money, cent, time, w...
# 7              7.0  place, land, country, settlement, town, year, ...
# 1              1.0  city, house, town, building, street, place, sh...
# 15            15.0  day, eye, hand, heart, room, life, mind, head,...
# 10            10.0  church, people, place, person, year, immigrant...
# 16            16.0  company, fire, day, horse, wagon, animal, wate...
# 19            19.0  people, state, country, law, year, hand, world...
# 9              9.0  family, friend, girl, woman, daughter, death, ...
# 6              6.0  time, account, month, manner, situation, natur...
# 8              8.0  man, government, day, soldier, war, member, ho...
# 12            12.0  foot, gold, time, snow, road, water, place, ma...
# 13            13.0  body, world, food, man, business, water, ship,...

# %%
# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts.rename('counts'), topic_contribution.rename('contribution')], axis=1).sort_values(by = 'Dominant_Topic')
df_dominant_topics
# Out:
#     Dominant_Topic                                     Topic_Keywords  counts  \
# 0                0  time, people, day, give, person, manner, order...       8
# 1                1  place, town, day, walk, house, travel, remain,...      14
# 2                2  land, country, acre, farm, dollar, farmer, sel...      79
# 3                3  week, child, day, critchlow, stay, evening, fe...     171
# 4                4  year, letter, send, family, brother, live, hea...      36
# 5                5  sister, school, man, room, visit, mother, give...      51
# 6                6  write, book, send, work, copy, receive, paper,...      41
# 7                7  people, state, year, city, world, dollar, empl...      14
# 8                8  day, ship, water, bed, passenger, pass, wind, ...      28
# 9                9  place, year, church, country, settlement, sett...      25
# 10              10  work, day, give, time, place, money, pay, mont...      16
# 11              11  letter, write, feel, child, hear, mother, send...      71
# 12              12  call, man, law, country, head, enemy, crime, g...      15
# 13              13  hand, life, time, give, friend, mind, eye, hea...       7
#
#     contribution
# 0         0.0139
# 1         0.0243
# 2         0.1372
# 3         0.2969
# 4         0.0625
# 5         0.0885
# 6         0.0712
# 7         0.0243
# 8         0.0486
# 9         0.0434
# 10        0.0278
# 11        0.1233
# 12        0.0260
# 13        0.0122

# %%
df_dominant_topics.to_csv("20240222__PhD_TopicsLtrMAL14.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   docID-AT          576 non-null    int64
#  1   docauthorid       576 non-null    object
#  2   docauthorname     576 non-null    object
#  3   docid             576 non-null    object
#  4   sourcetitle       576 non-null    object
#  5   docyear           573 non-null    float64
#  6   docmonth          519 non-null    float64
#  7   docday            474 non-null    float64
#  8   authorgender      576 non-null    object
#  9   agewriting        460 non-null    float64
#  10  birthyear         463 non-null    float64
#  11  deathyear         449 non-null    float64
#  12  religionNew       450 non-null    object
#  13  relMin            474 non-null    object
#  14  nationalOrigin    575 non-null    object
#  15  britishEmpire_EU  573 non-null    object
#  16  translated        576 non-null    bool
#  17  authorLocation    576 non-null    object
#  18  socialClass       513 non-null    object
#  19  A                 513 non-null    object
#  20  I                 513 non-null    object
#  21  CCP               513 non-null    object
#  22  Unknown           513 non-null    object
#  23  wageLabour        513 non-null    object
#  24  publicLetter      16 non-null     object
#  25  text              576 non-null    object
#  26  scoreNeg          576 non-null    float64
#  27  scorePos          576 non-null    float64
#  28  scoreNeu          576 non-null    float64
#  29  scoreCompound     576 non-null    float64
#  30  topicNumber       576 non-null    int64
# dtypes: bool(1), float64(10), int64(2), object(18)
# memory usage: 135.7+ KB

# %%
df.to_csv("20240222_PhD_Data4NER-Letter.csv")
